# %%
#create dataframe
import pandas as pd
df = pd.read_excel('/content/NIET (Responses).xlsx')
df
# Out:
#                   Timestamp      Enter your Name Enter your age  \
# 0   2023-02-13 21:48:49.456    Aadarsh Chaudhary          16-20
# 1   2023-02-13 21:51:52.334    Akhil chaturvedi           16-20
# 2   2023-02-13 22:04:07.233         Amrit Dubey           16-20
# 3   2023-02-13 22:35:43.102        Babloo kumar           16-20
# 4   2023-02-13 21:51:24.315  Harsh Vardhan Singh          16-20
# ..                      ...                  ...            ...
# 274 2023-02-14 18:53:02.045      Dhanya Dwivedi           16-20
# 275 2023-02-14 18:55:58.501       Arshia Talwar           16-20
# 276 2023-02-14 18:58:07.740     Pratyush sachan           16-20
# 277 2023-02-14 19:12:58.965      Anshika Jaiswal          16-20
# 278 2023-02-14 21:03:16.960         Neha Chauhan          16-20
#
#                  Your Branch
# 0    ARTIFICIAL INTELLIGENCE
# 1    ARTIFICIAL INTELLIGENCE
# 2    ARTIFICIAL INTELLIGENCE
# 3    ARTIFICIAL INTELLIGENCE
# 4    ARTIFICIAL INTELLIGENCE
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Timestamp        278 non-null    datetime64[ns]
#  1   Enter your Name  278 non-null    object
#  2   Enter your age   278 non-null    object
#  3   Your Branch      278 non-null    object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 8.8+ KB

# %%
df.size
# Out:
# 1116

# %%
df.head()#display 1st 5 row indexes
# Out:
#                 Timestamp      Enter your Name Enter your age  \
# 0 2023-02-13 21:48:49.456    Aadarsh Chaudhary          16-20
# 1 2023-02-13 21:51:52.334    Akhil chaturvedi           16-20
# 2 2023-02-13 22:04:07.233         Amrit Dubey           16-20
# 3 2023-02-13 22:35:43.102        Babloo kumar           16-20
# 4 2023-02-13 21:51:24.315  Harsh Vardhan Singh          16-20
#
#                Your Branch
# 0  ARTIFICIAL INTELLIGENCE
# 1  ARTIFICIAL INTELLIGENCE
# 2  ARTIFICIAL INTELLIGENCE
# 3  ARTIFICIAL INTELLIGENCE
# 4  ARTIFICIAL INTELLIGENCE
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2761436223326199031 = autoviz.get_df('df_2761436223326199031')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
# ...

# %%
df.head(69) # display the 1st 69 row indexes
# Out:
#                  Timestamp      Enter your Name Enter your age  \
# 0  2023-02-13 21:48:49.456    Aadarsh Chaudhary          16-20
# 1  2023-02-13 21:51:52.334    Akhil chaturvedi           16-20
# 2  2023-02-13 22:04:07.233         Amrit Dubey           16-20
# 3  2023-02-13 22:35:43.102        Babloo kumar           16-20
# 4  2023-02-13 21:51:24.315  Harsh Vardhan Singh          16-20
# ..                     ...                  ...            ...
# 64 2023-02-13 22:12:39.332     Palak Agnihotri           16-20
# 65 2023-02-13 21:52:28.148      Suryansh Gupta           16-20
# 66 2023-02-13 21:57:31.320        Mansi pandey           16-20
# 67 2023-02-14 01:14:21.648                    A          16-20
# 68 2023-02-13 22:03:58.081         Aman Bajpai           16-20
#
#                 Your Branch
# 0   ARTIFICIAL INTELLIGENCE
# 1   ARTIFICIAL INTELLIGENCE
# 2   ARTIFICIAL INTELLIGENCE
# 3   ARTIFICIAL INTELLIGENCE
# 4   ARTIFICIAL INTELLIGENCE
# ..                      ...
# ...

# %%
df.tail() #shows last 5 row index
# Out:
#                   Timestamp   Enter your Name Enter your age       Your Branch
# 274 2023-02-14 18:53:02.045   Dhanya Dwivedi           16-20               CSE
# 275 2023-02-14 18:55:58.501    Arshia Talwar           16-20  COMPUTER SCIENCE
# 276 2023-02-14 18:58:07.740  Pratyush sachan           16-20               IOT
# 277 2023-02-14 19:12:58.965   Anshika Jaiswal          16-20               CSE
# 278 2023-02-14 21:03:16.960      Neha Chauhan          16-20      DATA SCIENCE
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
df.tail(69) #show last 69 row index
# Out:
#                   Timestamp      Enter your Name Enter your age  \
# 210 2023-02-14 08:15:54.446  Aditya Kumar Gupta           16-20
# 211 2023-02-13 21:55:29.036         Anjali singh          16-20
# 212 2023-02-13 21:47:34.120      Anshika Pathak           16-20
# 213 2023-02-13 21:47:44.463        Arpit Sharma           16-20
# 214 2023-02-13 21:49:21.468        Hariom tiwari          16-20
# ..                      ...                  ...            ...
# 274 2023-02-14 18:53:02.045      Dhanya Dwivedi           16-20
# 275 2023-02-14 18:55:58.501       Arshia Talwar           16-20
# 276 2023-02-14 18:58:07.740     Pratyush sachan           16-20
# 277 2023-02-14 19:12:58.965      Anshika Jaiswal          16-20
# 278 2023-02-14 21:03:16.960         Neha Chauhan          16-20
#
#              Your Branch
# 210                  ECE
# 211  INFORMATION & TECH.
# 212  INFORMATION & TECH.
# 213  INFORMATION & TECH.
# 214  INFORMATION & TECH.
# ..                   ...
# ...

# %%
import seaborn as sns
sns.distplot(df['Enter your age']) #this will show ERROR coz string can not be displayed in graph
# Out:
# <ipython-input-10-c4f9aae8047f>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Enter your age']) #this will show ERROR coz string can not be displayed in graph
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c4f9aae8047f> in <cell line: 2>()
#       1 import seaborn as sns
# ----> 2 sns.distplot(df['Enter your age']) #this will show ERROR coz string can not be displayed in graph
#
# ...

# %%
#want to know how many students are of similar age group
df['Enter your age'].value_counts()
# Out:
# 16-20    256
# 20-24     21
# 24-26      1
# Name: Enter your age, dtype: int64

# %%
#now we can convert this data into bar
df['Enter your age'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
#want to know how many students are of similar branch
df['Your Branch'].value_counts()
# Out:
# DATA SCIENCE                                  80
# CYBER SECURITY                                36
# IOT                                           25
# BIO-TECH                                      23
# CSE                                           21
# ECE                                           21
# ARTIFICIAL INTELLIGENCE                       20
# ARTIFICIAL INTELLIGENCE & MACHINE LEARNING    15
# INFORMATION & TECH.                           12
# COMPUTER SCIENCE                              11
# CSE - regional                                 4
# Computer Science                               1
# Computer Science (CS)                          1
# CS                                             1
# Computer science                               1
# Computer science                               1
# Computer Science                               1
# M.CA                                           1
# MBA                                            1
# ...

# %%
#similarly i want to convert this data in bar
df['Your Branch'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
#similarly i want to convert this data in pie chart
df['Your Branch'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='Your Branch'>

# %%
#similarly i want to convert this data in pie chart with legend
df['Your Branch'].value_counts().plot(kind = 'pie').legend( loc ="lower right")

# %%
#similarly i want to convert this data in pie chart with explode
df['Your Branch'].value_counts().plot(kind = 'pie',explode = [0.09,0.1,0.01,0.02,0.02,0.02,0.2,0.2,0.2,0.2,0.6,0.4,0.1,2.2,2.2,2.2,2.2,2.2,2.2,2.2,2.2])
# Out:
# <Axes: ylabel='Your Branch'>

# %%
#divid the data into input & output
x = df.iloc[:,1].values
y = df.iloc[:,0].values
print(x)
print(y)
# Out:
# ['Aadarsh Chaudhary' 'Akhil chaturvedi ' 'Amrit Dubey ' 'Babloo kumar '
#  'Harsh Vardhan Singh' 'Kunj Singhal ' 'Nuved Ahmad' 'Prasoon'
#  'Samit Srivastav ' 'Shan singh' 'Shivam maurya' 'Shivam Singh '
#  'Siddharth Mishra' 'Suryaveer Singh ' 'TARANG VERMA ' 'VAIBHAV GUPTA'
#  'Yogendra Kumar ' 'Ankit keshri ' 'Mo ismail ' 'Pratiksha Maurya'
#  'Adarsh ojha' 'Arya Singh ' 'Happy Singh' 'HARSHIT VERMA' 'Manasavi'
#  'Nitish vashishtha ' 'Raushan Kumar ' 'Shikha' 'Utkarsh Chauhan '
#  'Vineet Kumar ' 'Ayush Bhardwaj ' 'Vishal' 'Andleena Ameer '
#  'Aryan Kushwaha' 'Devashish Sharma' 'Ishita garg' 'Kaushal Dubey '
#  'Kritika Kumari' 'Mannan Siddique' 'MD RIZWAN ALAM' 'Meenakshi rawat '
#  'Pragya singh' 'Purnima Singh ' 'Sakshi singh ' 'Sanjeev Kumar Bhashkar '
#  'Satya gupta' 'Saumya Gupta ' 'Shagun Saini ' 'Sonika kumari '
#  'Smita Jaiswal ' 'Manpreet Kaur' 'Shreya kumari' 'Diya Tyagi'
#  'Harshit Srivastava ' 'Aishni Sharma' 'Aman Sharma' 'Disha Dubey '
# ...
